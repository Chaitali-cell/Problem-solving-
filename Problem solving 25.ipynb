# %%
1.#Time calculator
distance = float(input("Enter distance: "))
speed = float(input("Enter speed: "))
time = distance / speed
print("Time =", time)
# Out:
# Enter distance:  6
# Enter speed:  7
# Time = 0.8571428571428571

# %%
2.#convert minutes to hours
minutes = int(input("Enter minutes: "))
hours = minutes // 60
remaining = minutes % 60
print(hours, "hours", remaining, "minutes")
# Out:
# Enter minutes:  240
# 4 hours 0 minutes

# %%
3.#Convert Days to Years, Months and Days
days = int(input("Enter days: "))
years = days // 365
months = (days % 365) // 30
remaining = (days % 365) % 30
print(years, "Years")
print(months, "Months")
print(remaining, "Days")
# Out:
# Enter days:  420
# 1 Years
# 1 Months
# 25 Days

# %%
4.#Convert Rupees to Paise
rupees = float(input("Enter rupees: "))
paise = rupees * 100
print("Paise =", paise)
# Out:
# Enter rupees:  20
# Paise = 2000.0

# %%
5.#Convert Paise to Rupees
paise = float(input("Enter paise: "))

rupees = paise / 100

print("Rupees =", rupees)
# Out:
# Enter paise:  2000
# Rupees = 20.0

# %%
6.#Convert Kilometers to Meters
km = float(input("Enter kilometers: "))
meters = km * 1000
print("Meters =", meters)
# Out:
# Enter kilometers:  250
# Meters = 250000.0

# %%
7.#Convert Meters to Kilometers
meters = float(input("Enter meters: "))
km = meters / 1000
print("Kilometers =", km)
# Out:
# Enter meters:  150
# Kilometers = 0.15

# %%
8.#Convert Kilograms to Grams
kg = float(input("Enter kilograms: "))
grams = kg * 1000
print("Grams =", grams)
# Out:
# Enter kilograms:  200
# Grams = 200000.0

# %%
9.#Convert Grams to Kilograms
grams = float(input("Enter grams: "))

kg = grams / 1000

print("Kilograms =", kg)
# Out:
# Enter grams:  1000
# Kilograms = 1.0

# %%
10.#Find Total Seconds
hours = int(input("Hours: "))
minutes = int(input("Minutes: "))
seconds = int(input("Seconds: "))

total = hours * 3600 + minutes * 60 + seconds

print("Total Seconds =", total)
# Out:
# Hours:  1
# Minutes:  20
# Seconds:  60
# Total Seconds = 4860
