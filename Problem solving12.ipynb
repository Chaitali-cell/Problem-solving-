# %%
#WAP TO PRINT SET
s3 = {1,2,2,3,4,5,6,4,6,7}
s3
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
#WAP TO ADD VALUE IN SET
s3.add(20)
s3
# Out:
# {1, 2, 3, 4, 5, 6, 7, 20}

# %%
#WAP TO ADD SET
s3.update("abc")
s3
# Out:
# {1, 2, 20, 3, 4, 5, 6, 7, 'a', 'b', 'c'}

# %%
#TO PRINT TYPE OF COLLECTION
s1 = {}
print(type(s1))
# Out:
# <class 'dict'>

# %%
s2 = set()
print(type(s2))
# Out:
# <class 'set'>

# %%
#WAP TO ADD STRING
s3.add("pune")
s3
# Out:
# {1, 2, 20, 3, 4, 5, 6, 7, 'a', 'b', 'c', 'pune'}

# %%
#WAP TO REMOVE STRING
s3.remove("pune")
s3
# Out:
# {1, 2, 20, 3, 4, 5, 6, 7, 'a', 'b', 'c'}

# %%
s3.remove("c")
s3
# Out:
# {1, 2, 20, 3, 4, 5, 6, 7, 'a', 'b'}

# %%
#WAP to discard character
s3.discard('a')
s3
# Out:
# {1, 2, 20, 3, 4, 5, 6, 7, 'b'}

# %%
s4 = {3,"ram",78.86}
s4
# Out:
# {3, 78.86, 'ram'}

# %%
#wap to remove value in set
s3.remove(20)
s3
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'b'}

# %%
print(s3.discard)
# Out:
# <built-in method discard of set object at 0x0000021D8D541FC0>
