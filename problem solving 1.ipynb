# %%
#WAP to find area of circle
rad=int(input("Enter radius"))
area_of_circle=3.14*rad**2
print(f"Area of circle {area_of_circle} is {n1}")
# Out:
# Enter radius 2
# Area of circle 12.56 is 2

# %%
#WAP to find squareroot
a=float(input("Enter number"))
square_root=a**1/2
print(f"Square root of {a} is {square_root}")
# Out:
# Enter number 4
# Square root of 4.0 is 2.0

# %%
#WAP to find  cuberoot
a=int(input("Enter number"))
cube_root=a**1/3
print(f"Cube root of {a} is {cube_root}")
# Out:
# Enter number 9
# Cube root of 9 is 3.0

# %%
#WAP to find area of square
num=int(input("Enter side"))
area_of_square=num**2
print(f"Area of square {num} is {area_of_square}")
# Out:
# Enter side 2
# Area of square 2 is 4

# %%
#WAP to find area of triangle
num1=int(input("Enter Length"))
num2=int(input("Enter Breadth"))
area_of_triangle=1/2*num1*num2
print(f"Area of triangle is {area_of_triangle}")
# Out:
# Enter Length 2
# Enter Breadth 3
# Area of triangle is 3.0

# %%
#WAP to find area of rectangle
num1=int(input("Enter Length"))
num2=int(input("Enter Breadth"))
num3=int(input("Enter height"))
area_of_rectangle=num1*num2*num3
print(f"Area of rectangle is {area_of_rectangle}")
# Out:
# Enter Length 2
# Enter Breadth 3
# Enter height 4
# Area of rectangle is 24

# %%
#WAP to find quotient
num1=10
num2=5
div=num1//num2
print(f" quotient of num1 and num2 is {div}")
# Out:
#  quotient of num1 and num2 is 2

# %%
#WAP for star program
rows = 5
for i in range(1,rows+1):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
#WAP for star program
rows=5
for i in range(rows,0,-1):
    print("*"*i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
#WAP to add two number
n1=int(input("Enter number"))
n2=int(input("Enter number"))     
add=n1+n2
print(f"addition of {n1} and {n2} is {add}")
# Out:
# Enter number 2
# Enter number 3
# addition of 2 and 3 is 5

# %%
#WAP for arithmetic operation
n1=int(input("Enter number"))
n2=int(input("Enter number"))
sub=n1-n2
mul=n1*n2
div=n1/n2
rem=n1%n2
print(f"subtraction of {n1} and {n2} is {sub}")
print(f"Multiplication of {n1} and {n2} is {mul}")
print(f"Division of {n1} and {n2} is {div}")
print(f"Remainder of {n1} and {n2} is {rem}")
# Out:
# Enter number 10
# Enter number 5
# subtraction of 10 and 5 is 5
# Multiplication of 10 and 5 is 50
#  Division of 10 and 5 is 2.0
#  Remainder of 10 and 5 is 0
