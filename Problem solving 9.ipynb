# %%
#WAP to print list
l1 = [3,4,2,1,5,6,7]
l1
# Out:
# [3, 4, 2, 1, 5, 6, 7]

# %%
#perform append operation on list
l1.append(8)
l1
# Out:
# [3, 4, 2, 1, 5, 6, 7, 8]

# %%
#perform insert operation on list
l1.insert(0,11)
l1
# Out:
# [11, 10, 3, 4, 2, 1, 5, 6, 7, 8, 10]

# %%
#perform insert operation on list
l1.insert(3,[400,500,600])
l1
# Out:
# [11, 10, 3, [400, 500, 600], [400, 500, 600], 4, 2, 1, 5, 6, 7, 8, 10]

# %%
#perform pop operation on list
l1.pop(3)
l1
# Out:
# [11, 10, 3, [400, 500, 600], 4, 2, 1, 5, 6, 7, 8, 10]

# %%
#perfrom extend operation on list
l1.extend([700,800,900])
l1
# Out:
# [11, 10, 3, [400, 500, 600], 4, 2, 1, 5, 6, 7, 8, 10, 700, 800, 900]

# %%
#perform pop operation on list
l1.pop()
l1
# Out:
# [11, 10, 3, [400, 500, 600], 4, 2, 1, 5, 6, 7, 8, 10, 700, 800]

# %%
#perform remove operation on list
l1.remove(3)
l1
# Out:
# [11, 10, [400, 500, 600], 4, 2, 1, 5, 6, 7, 8, 10, 700, 800]

# %%
#perform delete operation on list
del l1[3:4]
l1
# Out:
# [11, 10, [400, 500, 600], 1, 5, 6, 7, 8, 10, 700, 800]

# %%
#find length of list
len(l1)
# Out:
# 11
